# %%
from astropy.io import fits
import glob
import numpy as np
np.version.version
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
Mercury_ims = glob.glob('*.FIT')
#import mercury images

# %%
mercury = []
for fit in Mercury_ims:
    mercury.append(fits.open(fit)[0].data)

# %%
for image in mercury:
    plt.imshow(image, cmap='magma', aspect='equal', interpolation='none')
    plt.show()

# %%
for img in mercury:
    print(np.argmax(img))
# Out:
# 2782104
# 2782104

# %%
for img in mercury:
    print(np.shape(img))
# Out:
# (3520, 4656)
# (3520, 4656)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-26027307869a> in <module>()
# ----> 1 mercury[0][2782104]
#
# IndexError: index 2782104 is out of bounds for axis 0 with size 3520

# %%
maxrow = np.argmax(mercury[0], axis=1)

# %%
# dim = int(np.sqrt(len(mercury[0])))
col = np.argmax(mercury[0]) % 4656
row = int(np.argmax(mercury[0])/4656)

# %%
print(col)
print(row)
# Out:
# 2472
# 597

# %%
3520*4656
# Out:
# 16389120

# %%
row = 2782104/4656
col = 2782104/3520

# %%
print(row,col)
# Out:
# 597.5309278350516 790.3704545454545

# %%
width =12
col_low = col - 30*width
col_high = col + 30*width
row_low = row - width
row_high = row + width

# %%
spec = mercury[0][row_low:row_high,col_low:col_high]

# %%
plt.imshow(spec)
plt.gcf().set_size_inches(20,12)

# %%
plt.plot(maxrow)
